# %%
import googleapiclient.discovery as gapi
from googleapiclient.errors import HttpError
import pandas as pd
import os
import time
import concurrent.futures
import datetime

# %% [markdown]
# # Setup

# %%
CURRENT_FOLDER = 'C:\\Coding Projects\\YoutubeCookingData\\'

with open(CURRENT_FOLDER + "apiKeys.txt") as f:
    YOUTUBE_API_KEY = f.read()
youtube_service = gapi.build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)

# %% [markdown]
# # Final Functions

# %%
from datetime import date


def jsonFieldHandler(json, key1, key2='', key3='', key4=''):
    # If the key doesn't exist, return ''
    try:
        if(key1 and key2 and key3 and key4):
            return json[key1][key2][key3][key4]
        elif(key1 and key2 and key3):
            return json[key1][key2][key3]
        elif(key1 and key2):
            return json[key1][key2]
        elif(key1):
            return json[key1]
    except:
        return ''

# Gets the data for all channels and parses it
def getChannelDataHandler(channel_id_list):
    channel_dict_list = []
    channel_response_json = []
    
    # Get all fields for Channel
    for i in range(0, len(channel_id_list), 50):
        channel_response_json += getChannelData(channel_id_list[i:i+50])
        
    # Parse response into dictionary
    for result in channel_response_json:
#         print(f"LOG: Fetching Data for Channel ID {result['id']}")
        channel_dict = {}
        
        channel_dict['Channel ID'] = jsonFieldHandler(result, 'id')
        channel_dict['Title'] = jsonFieldHandler(result, 'snippet','title')
        channel_dict['Description'] = jsonFieldHandler(result, 'snippet','description')
        channel_dict['URL'] = jsonFieldHandler(result, 'snippet','customUrl')
        channel_dict['Channel Created Date'] = jsonFieldHandler(result, 'snippet','publishedAt')
        channel_dict['Thumbnail URL'] = jsonFieldHandler(result, 'snippet', 'thumbnails', 'high', 'url')
        channel_dict['Language'] = jsonFieldHandler(result, 'snippet', 'defaultLanguage')
        channel_dict['Country'] = jsonFieldHandler(result, 'snippet', 'country')
        channel_dict['Views'] = jsonFieldHandler(result, 'statistics', 'viewCount')
        channel_dict['Subscriber Count'] = jsonFieldHandler(result, 'statistics', 'subscriberCount')
        channel_dict['Video Count'] = jsonFieldHandler(result, 'statistics', 'videoCount')
        channel_dict['Topics'] = jsonFieldHandler(result, 'topicDetails', 'topicIds')
        channel_dict['Topic Categories'] = jsonFieldHandler(result, 'topicDetails', 'topicCategories')
        channel_dict['Upload Playlist ID'] = jsonFieldHandler(result, 'contentDetails', 'relatedPlaylists', 'uploads')

        channel_dict_list.append(channel_dict)
        
    return pd.DataFrame(channel_dict_list)

# Gets all fields for a given list of channel
def getChannelData(channel_id_list):
    request = youtube_service.channels().list(
        part=['id', 'snippet', 'statistics', 'topicDetails', 'contentDetails'],
        id=channel_id_list,
        maxResults = 50
    )
    
    results = request.execute()
    return results['items']

# Returns the upload playlist for a list of channel ids
def getUploadPlaylistsforChannelHandler(channel_id_list):
    channel_response_json = []
    upload_playlist_list = []
    
    # Get upload playlists
    for i in range(0, len(channel_id_list), 50):
        channel_response_json += getUploadPlaylistsforChannel(channel_id_list[i:i+50])
    
    # Get only the channel's upload playlist id
    return [jsonFieldHandler(channel_json, 'contentDetails', 'relatedPlaylists', 'uploads') for channel_json in channel_response_json]

# Gets upload playlist ID for a list of channel IDs
def getUploadPlaylistsforChannel(channel_id_list):
    request = youtube_service.channels().list(
    part=['contentDetails'],
        id=channel_id_list,
        maxResults=50
    )
    
    result = request.execute()
    
    return result['items']
    
    
    
# Function that returns all videoIds for a given channel's upload playlist
def getVideoListForPlaylist(upload_playlist_id, page_token=''):
    video_ids = []

    t1 = time.time()
    
    request = youtube_service.playlistItems().list(
        part="contentDetails",
        playlistId=upload_playlist_id,
        maxResults=50,
        pageToken=page_token
    )
    
    try:
        results = request.execute()
        result_videos = results['items']
    except HttpError as err:
        appendToLog(HttpError)
        raise err
    
    # If there is a next page then append videos to result array
    if('nextPageToken' in results):
        nextPage = results['nextPageToken']
        result_videos += getVideoListForPlaylist(upload_playlist_id, nextPage)
    
    # If not called by another instance of this function, return only IDs
    if(page_token == ''):
#         print(f"LOG: Working on Channel ID {channelId}.")
        t2 = time.time()
        appendToLog(f'Time elapsed for videos of playlist {upload_playlist_id} {t2-t1} for {len(result_videos)} videos')
        return [vid['contentDetails']['videoId'] for vid in result_videos]
    else:
        # If recursing, return whole response list
        return result_videos

# Function that parses the return JSON from getVideoListForPlaylist and gets additional columns
def getVideoDataHandler(video_id_list):
    video_response_json = []
    video_dict_list = []
    
    # Get all fields for Video
    for i in range(0, len(video_id_list), 50):
        try:
            video_response_json += getVideoData(video_id_list[i:i+50])
        except HttpError as err:
            raise err
    
    # Parse response into dictionary
    for result in video_response_json:
#         print(f"\tLOG: Fetching Data for Video ID {result['id']}")
        video_dict = {}
        
        video_dict['Title'] = jsonFieldHandler(result, 'snippet', 'title')
        video_dict['Video ID'] = jsonFieldHandler(result, 'id')
        video_dict['Channel ID'] = jsonFieldHandler(result, 'snippet', 'channelId')
        video_dict['Duration'] = jsonFieldHandler(result, 'contentDetails', 'duration')
        video_dict['Description'] = jsonFieldHandler(result, 'snippet', 'description')
        video_dict['Publish Date'] = jsonFieldHandler(result, 'snippet', 'publishedAt')
        video_dict['Thumbnail URL'] = jsonFieldHandler(result, 'snippet', 'thumbnails', 'high',  'url')
        video_dict['View Count'] = jsonFieldHandler(result, 'statistics', 'viewCount')
        video_dict['Like Count'] = jsonFieldHandler(result, 'statistics', 'likeCount')
        video_dict['Comment Count'] = jsonFieldHandler(result, 'statistics', 'commentCount')        
        video_dict['Video Definition'] = jsonFieldHandler(result, 'contentDetails', 'definition')
        video_dict['Default Audio Language'] = jsonFieldHandler(result, 'snippet', 'defaultAudioLanguage')
        video_dict['Tags'] = jsonFieldHandler(result, 'snippet', 'tags')
        video_dict['Category ID'] = jsonFieldHandler(result, 'snippet', 'categoryId')
        video_dict['Topic Details'] = jsonFieldHandler(result, 'topicDetails')
        video_dict['Made for Kids'] = jsonFieldHandler(result, 'status', 'madeForKids')
        video_dict['Favorite Count'] = jsonFieldHandler(result, 'statistics', 'favoriteCount')
        video_dict_list.append(video_dict)
        
    return pd.DataFrame(video_dict_list)
     
def getVideoData(list_of_videos):
    request = youtube_service.videos().list(
        part=['contentDetails', 'liveStreamingDetails', 'id',
              'snippet', 'statistics', 'status', 'topicDetails'],
        id=list_of_videos,
        maxResults=50,
    )
    
    try:
        results = request.execute()
        return results['items']
    except HttpError as err: 
        # If error, return 
        appendToLog(HttpError)
        raise err

# Gets the comment threads for all videos in a given list
def getCommentThreadsHandler(list_of_videos):
    dataframes_list = []
    
    for video_id in list_of_videos:
        try:
            dataframes_list.append(getCommentsForVideo(video_id))
        except HttpError as err:
            # If it is bad request, try again in 5 seconds. Else raise error
            if(err.resp.status == 400):
                try:
                    appendToLog(f"Potentially transient ({err.resp.status}), trying again for video {video_id}")
                    time.sleep(600)
                    dataframes_list.append(getCommentsForVideo(video_id))
                except HttpError as err:
                    raise err
            else:
                raise err

    return pd.concat(dataframes_list, ignore_index=True)

# Get list of comment threads for a given video, returns a dataframe
def getCommentsForVideo(video_id, page_token=""):
#     print(f"\tLOG: Fetching Comment Data for Video ID {video_id}, {page_token}")
    t1 = time.time()
    request = youtube_service.commentThreads().list(
        part=['id', 'replies', 'snippet'],
        videoId=video_id,
        maxResults=100,
        pageToken=page_token
    )

    try:
        results = request.execute()
        result_comments = results['items']
    
        if('nextPageToken' in results):
            next_page = results['nextPageToken']
            result_comments += getCommentsForVideo(video_id, next_page)
        
        # If not recursing, parse the full response
        if(page_token == ''):
            t2 = time.time()
            appendToLog(f'Time elapsed for comments on video {video_id} {t2-t1} for {len(result_comments)} comments')
            return parseCommentThreadResponse(result_comments)
        else: 
            # Return raw results if called by another instance of this function
            return result_comments
    except HttpError as err:
        appendToLog(f'{err.resp.status} - {err._get_reason()} - {video_id} with page {page_token}')
        raise err

# Parse comment threads response JSON
def parseCommentThreadResponse(list_of_threads):
    thread_dict_list = []
    
    for thread in list_of_threads:
#         print(f"\t\tLOG: Fetching Data for Comment Thread ID {thread['id']}")
        thread_dict = {}
        
        thread_dict['Comment Thread ID'] = jsonFieldHandler(thread, 'id')
        thread_dict['Video ID'] = jsonFieldHandler(thread, 'snippet', 'videoId')
        thread_dict['Top Level Comment'] = jsonFieldHandler(thread, 'snippet', 'topLevelComment')
        thread_dict['Total Replies'] = jsonFieldHandler(thread, 'snippet', 'totalReplyCount')
        thread_dict['Can Reply'] = jsonFieldHandler(thread, 'snippet', 'canReply')
        thread_dict['Replies'] = jsonFieldHandler(thread, 'replies')
        
        thread_dict_list.append(thread_dict)
    
    return pd.DataFrame(thread_dict_list)

def appendToLog(message): 
    print(message)
    current_time = datetime.datetime.now()
    
    file_path = CURRENT_FOLDER + f"Log {current_time.year}-{current_time.month}-{current_time.day}.txt"

    if(os.path.exists(file_path)):
        append_write = 'a'
    else:
        append_write ='w'
    
    with open(file_path, append_write) as f:
        f.write(message + '\n')

def main(channels_flag=True, videos_flag=True, comments_flag=True, current_folder=''):
#     CHANNEL_LIST = pd.read_csv("Channel IDs.csv")['ID'].to_list()
    appendToLog(f"Starting execution for channel data: {channels_flag}, video data: {videos_flag}, comment data: {comments_flag}")
    CHANNEL_ID_TOTAL_DF = pd.read_csv(current_folder + "Channel IDs.csv")

    # File Paths
    channels_file_path = current_folder + "Channel Data.csv"
    videos_file_path = current_folder + "Video Data.csv"
    comments_file_path = current_folder + "Comment Data.csv"
    
    # If Channels step is done, skip
    if(channels_flag):
        # If the file exists check how many channels still need to be queried, else get the whole list
        if(os.path.exists(channels_file_path)):
            # Get list of channel ids that have been queried and compare against the total list of ids
            channel_data_done_ids = pd.read_csv(channels_file_path)['Channel ID'].to_list()
            
            channelIdsToFetch = CHANNEL_ID_TOTAL_DF[~CHANNEL_ID_TOTAL_DF['ID'].isin(channel_data_done_ids)]['ID'].to_list()
            appendToLog(f"{len(channel_data_done_ids)} channels already done out of {CHANNEL_ID_TOTAL_DF['ID'].shape[0]}")
        else:
            channelIdsToFetch = CHANNEL_ID_TOTAL_DF['ID'].to_list()
            appendToLog(f"No channels already done, querying all {len(channelIdsToFetch)} IDs")
        
        # If there are channels to fetch, get data and write to csv
        if(len(channelIdsToFetch) > 0):
            channels_df = getChannelDataHandler(channelIdsToFetch)
            channels_df.to_csv(channels_file_path)
    
    # Check video progress, skip if done
    if(videos_flag):
        video_ids = []
        videos_list = []
        # Check if a given channel has already had its videos fetched
        if(os.path.exists(videos_file_path)):
            channel_data_done_ids_videos = pd.read_csv(videos_file_path)['Channel ID'].unique().tolist()
            
            # TODO, switch this to load Upload Playlist IDs directly
            channel_ids_to_fetch_videos = CHANNEL_ID_TOTAL_DF[~CHANNEL_ID_TOTAL_DF['ID'].isin(channel_data_done_ids_videos)]['ID'].to_list()
            playlist_ids_to_fetch_videos = getUploadPlaylistsforChannelHandler(channel_ids_to_fetch_videos)
            appendToLog(f"{len(channel_data_done_ids_videos)} channel's videos already done out of {len(CHANNEL_ID_TOTAL_DF['ID'].to_list())}")
            # Read in current data
            videos_list.append(pd.read_csv(videos_file_path))
        else:
            channel_ids_to_fetch_videos = CHANNEL_ID_TOTAL_DF['ID'].to_list()
            appendToLog(f"No channel's videos already done, querying all {len(channel_ids_to_fetch_videos)} channels")
            playlist_ids_to_fetch_videos = getUploadPlaylistsforChannelHandler(channel_ids_to_fetch_videos)
        for playlist_id in playlist_ids_to_fetch_videos:
            try:
                video_ids = getVideoListForPlaylist(playlist_id)
                videos_list.append(getVideoDataHandler(video_ids))
            except HttpError as err:
                appendToLog(f"Error caught while fetching video data, ending execution")
                # Write current data to file
                pd.concat(videos_list, ignore_index=True).to_csv(videos_file_path)
                return  

        # If all videos are read successfully, write to file and continue
        pd.concat(videos_list, ignore_index=True).to_csv(videos_file_path)
            
    if(comments_flag):
        comment_ids = []
        comments_list = []
        if(os.path.exists(videos_file_path)):
            videos_data_total_ids_df = pd.read_csv(videos_file_path)
            if(os.path.exists(comments_file_path)):
                videos_data_done_ids_comments = pd.read_csv(comments_file_path)['Video ID'].unique().tolist()
                # Only fetch videos that have comments
                video_ids_to_fetch_comments = videos_data_total_ids_df[~videos_data_total_ids_df['Video ID'].isin(videos_data_done_ids_comments) & videos_data_total_ids_df['Comment Count'] > 0]['Video ID'].to_list()
                appendToLog(f"Done {len(videos_data_done_ids_comments)} video's comments out of {videos_data_total_ids_df.shape[0]}")
                # Read in current data
                comments_list.append(pd.read_csv(comments_file_path))
            else:
                # Only fetch videos that have comments
                video_ids_to_fetch_comments = videos_data_total_ids_df[videos_data_total_ids_df['Comment Count'] > 0]['Video ID'].to_list()
                appendToLog(f"No comments done, getting data for all {len(video_ids_to_fetch_comments)} videos")
        else:
            appendToLog("No video data file, exiting")
            return
        for video_id in video_ids_to_fetch_comments:
            try:
                comments_list.append(getCommentThreadsHandler([video_id]))
            except HttpError as err:
                appendToLog(f"Error caught while fetching comment data, ending execution")
                # Write current data to file 
                pd.concat(comments_list, ignore_index=True).to_csv(comments_file_path)
                return
        # Write each video's comments to the file if not excepted
        pd.concat(comments_list, ignore_index=True).to_csv(comments_file_path)
                
    
#     comments_df = getCommentThreadsHandler(video_ids)    
#     comments_df.to_csv(comments_file_path)
    
#     return videos_df, comments_df
    return

# %%
main(current_folder=CURRENT_FOLDER)
# Out:
# Starting execution for channel data: True, video data: True, comment data: True
# No channels already done, querying all 59 IDs
# No channel's videos already done, querying all 59 channels
# 727 1
# 727 2
# 754 1
# 754 2
# 733 1
# 733 2
# 442 1
# 442 2
# 1349 1
# 1349 2
# 4359 1
# 4359 2
# 1091 1
# 1091 2
# 434 1
# 434 2
# 372 1
# 372 2
# 93 1
# 93 2
# 606 1
# 606 2
# 418 1
# 418 2
# 424 1
# 424 2
# 1991 1
# 1991 2
# 513 1
# 513 2
# 159 1
# 159 2
# 1579 1
# 1579 2
# 1881 1
# 1881 2
# 1781 1
# 1781 2
# 371 1
# 371 2
# 555 1
# 555 2
# 408 1
# 408 2
# 479 1
# 479 2
# 1967 1
# 1967 2
# 106 1
# 106 2
# 411 1
# 411 2
# 322 1
# 322 2
# 500 1
# 500 2
# 1741 1
# 1741 2
# 344 1
# 344 2
# 1059 1
# 1059 2
# 40 1
# 40 2
# 1055 1
# 1055 2
# 938 1
# 938 2
# 1330 1
# 1330 2
# 573 1
# 573 2
# 197 1
# 197 2
# 1346 1
# 1346 2
# 766 1
# 766 2
# 1748 1
# 1748 2
# 450 1
# 450 2
# 1791 1
# 1791 2
# 996 1
# 996 2
# 375 1
# 375 2
# 435 1
# 435 2
# 12697 1
# 12697 2
# 833 1
# 833 2
# 296 1
# 296 2
# 492 1
# 492 2
# 529 1
# 529 2
# 18 1
# 18 2
# 207 1
# 207 2
# 211 1
# 211 2
# 1579 1
# 1579 2
# 141 1
# 141 2
# 204 1
# 204 2
# 11 1
# 11 2
# 221 1
# 221 2
# No comments done, getting data for all 56324 videos
# 0 1
# Time elapsed for comments on video I0glbWBxeFc 0.2869858741760254 for 75 comments
# 1 2
# 1 1
# Time elapsed for comments on video ojhhNwIqOSM 0.1942763328552246 for 10 comments
# 2 2
# 2 1
# Time elapsed for comments on video _eLhSgcdDyM 0.18475866317749023 for 6 comments
# 3 2
# 3 1
# Time elapsed for comments on video PiwS8_SzS3Q 0.1757347583770752 for 5 comments
# 4 2
# 4 1
# Time elapsed for comments on video Lfmvf-D9U5s 0.8487324714660645 for 230 comments
# 5 2
# 5 1
# Time elapsed for comments on video zQgto9WXhlI 3.3167967796325684 for 995 comments
# 6 2
# 6 1
# Time elapsed for comments on video PhNTO23bH_o 0.5510077476501465 for 124 comments
# 7 2
# 7 1
# Time elapsed for comments on video R0Pu42Bo2A0 0.2613210678100586 for 67 comments
# 8 2
# 8 1
# Time elapsed for comments on video flkMQ-TtdCk 0.287766695022583 for 76 comments
# 9 2
# 9 1
# Time elapsed for comments on video Xak8mvujMNE 0.5225212574005127 for 104 comments
# 10 2
# 10 1
# Time elapsed for comments on video T46jRAHfHy4 0.26029253005981445 for 39 comments
# 11 2
# 11 1
# Time elapsed for comments on video AN4_1tG4JR0 0.6503839492797852 for 179 comments
# 12 2
# 12 1
# Time elapsed for comments on video hTlPNWmKjNw 1.055131196975708 for 267 comments
# 13 2
# 13 1
# Time elapsed for comments on video mIp3zqswz44 0.8910388946533203 for 219 comments
# 14 2
# 14 1
# Time elapsed for comments on video nsgpTK8JH4Q 0.2757577896118164 for 76 comments
# 15 2
# 15 1
# Time elapsed for comments on video Jxeprsp_dlM 0.5184764862060547 for 116 comments
# 16 2
# 16 1
# Time elapsed for comments on video H7D1yza2l8s 2.396940231323242 for 728 comments
# 17 2
# 17 1
# Time elapsed for comments on video cqeKPUDKqfI 0.259185791015625 for 70 comments
# 18 2
# 18 1
# Time elapsed for comments on video P_jsyG8o-ao 0.6077790260314941 for 186 comments
# 19 2
# 19 1
# Time elapsed for comments on video e-h8sNuMavE 0.5551700592041016 for 140 comments
# 20 2
# 20 1
# Time elapsed for comments on video x7mXZIyPcSs 2.5538506507873535 for 731 comments
# 21 2
# 21 1
# Time elapsed for comments on video z7ZzqmNPwGA 0.8142142295837402 for 224 comments
# 22 2
# 22 1
# Time elapsed for comments on video oO1n-WpCC5M 1.3251285552978516 for 399 comments
# 23 2
# 23 1
# Time elapsed for comments on video hvbMB-yak-M 2.1234991550445557 for 579 comments
# 24 2
# 24 1
# Time elapsed for comments on video Of_SHfHx1KE 2.2534677982330322 for 687 comments
# 25 2
# 25 1
# Time elapsed for comments on video HNK67XbV6mc 0.7227740287780762 for 194 comments
# 26 2
# 26 1
# Time elapsed for comments on video 3eJOokIb684 0.8043057918548584 for 201 comments
# 27 2
# 27 1
# Time elapsed for comments on video xajPqprt-CI 0.3230307102203369 for 97 comments
# 28 2
# 28 1
# Time elapsed for comments on video 0zVUUXr1z1A 1.1009578704833984 for 295 comments
# 29 2
# 29 1
# Time elapsed for comments on video vtTbCLaXqsE 0.24476933479309082 for 55 comments
# 30 2
# 30 1
# Time elapsed for comments on video Q_00XLpi8M4 0.5446867942810059 for 112 comments
# 31 2
# 31 1
# Time elapsed for comments on video wyD8bfC8A-Y 4.2539355754852295 for 1309 comments
# 32 2
# 32 1
# Time elapsed for comments on video _uO7DVxzzs4 0.9662423133850098 for 243 comments
# 33 2
# 33 1
# Time elapsed for comments on video buWML_1-uFA 0.6087875366210938 for 188 comments
# 34 2
# 34 1
# Time elapsed for comments on video PpB1TWPgUjI 28.240474224090576 for 8402 comments
# 35 2
# 35 1
# Time elapsed for comments on video dpCuYaEm3Sw 0.3349027633666992 for 97 comments
# 36 2
# 36 1
# Time elapsed for comments on video LsxSM4pBvd4 0.8735949993133545 for 246 comments
# 37 2
# 37 1
# Time elapsed for comments on video orWSXbrvr1o 2.501115083694458 for 739 comments
# 38 2
# 38 1
# Time elapsed for comments on video dfDv7nidGaA 0.5785000324249268 for 180 comments
# 39 2
# 39 1
# Time elapsed for comments on video PRfbtRSRuVM 3.8744773864746094 for 1107 comments
# 40 2
# 40 1
# Time elapsed for comments on video g8jCSXGUYrI 1.2082059383392334 for 331 comments
# 41 2
# 41 1
# Time elapsed for comments on video 4VVOkweUiNg 2.2703938484191895 for 710 comments
# 42 2
# 42 1
# Time elapsed for comments on video _vWbNQFK96Y 0.8325908184051514 for 230 comments
# 43 2
# 43 1
# Time elapsed for comments on video S31g485rsh0 0.5834934711456299 for 160 comments
# 44 2
# 44 1
# Time elapsed for comments on video YnLpnON9N7Q 0.3299086093902588 for 73 comments
# 45 2
# 45 1
# Time elapsed for comments on video Iq1wKhwZ9cU 0.9459857940673828 for 299 comments
# 46 2
# 46 1
# Time elapsed for comments on video xCp3eUd2iiQ 0.859173059463501 for 281 comments
# 47 2
# 47 1
# Time elapsed for comments on video 3rIYpDanqPE 1.1938128471374512 for 383 comments
# 48 2
# 48 1
# Time elapsed for comments on video cL3GhxtqAH8 2.4913899898529053 for 679 comments
# 49 2
# 49 1
# Time elapsed for comments on video Ekhj2e03QxE 0.48218464851379395 for 102 comments
# 50 2
# 50 1
# Time elapsed for comments on video Yfa7rlcYduc 0.6989374160766602 for 136 comments
# 51 2
# 51 1
# Time elapsed for comments on video 1Pv75eIMvyM 0.5261709690093994 for 121 comments
# 52 2
# 52 1
# Time elapsed for comments on video N1k_IhvFHfA 1.2125287055969238 for 366 comments
# 53 2
# 53 1
# Time elapsed for comments on video BrNDzBno6ys 0.5504577159881592 for 159 comments
# 54 2
# 54 1
# Time elapsed for comments on video I02SyoXGZbY 0.5734193325042725 for 167 comments
# 55 2
# 55 1
# Time elapsed for comments on video L8LcfZRcmJY 0.8923642635345459 for 263 comments
# 56 2
# 56 1
# Time elapsed for comments on video wZcc5dS_tiw 5.494835138320923 for 1641 comments
# 57 2
# 57 1
# Time elapsed for comments on video rv4b8bBKbBE 1.373337745666504 for 398 comments
# 58 2
# 58 1
# Time elapsed for comments on video edb24CaoCdM 0.5709068775177002 for 190 comments
# 59 2
# 59 1
# Time elapsed for comments on video rxQsiYXxGI4 0.4199979305267334 for 101 comments
# 60 2
# 60 1
# Time elapsed for comments on video gsR7hCsD6Lg 0.5853662490844727 for 167 comments
# 61 2
# 61 1
# Time elapsed for comments on video eBzHBXODBuw 5.048856735229492 for 1571 comments
# 62 2
# 62 1
# Time elapsed for comments on video EpvcvfAJ5vM 0.6154401302337646 for 195 comments
# 63 2
# 63 1
# Time elapsed for comments on video OAXYJ186Ji8 1.4488403797149658 for 405 comments
# 64 2
# 64 1
# Time elapsed for comments on video EaA_2Uop6O0 1.3570277690887451 for 395 comments
# 65 2
# 65 1
# Time elapsed for comments on video yDJ_DYje6kM 0.2802286148071289 for 88 comments
# 66 2
# 66 1
# Time elapsed for comments on video 6TFUzXZDjlk 0.9094488620758057 for 273 comments
# 67 2
# 67 1
# Time elapsed for comments on video zb22IlqUZPg 0.8629848957061768 for 244 comments
# 68 2
# 68 1
# Time elapsed for comments on video Z6jW-ngBvao 0.25373339653015137 for 66 comments
# 69 2
# 69 1
# Time elapsed for comments on video lsBBx4YQPfU 0.9994330406188965 for 257 comments
# 70 2
# 70 1
# Time elapsed for comments on video UO-zhWjamZ0 0.9635653495788574 for 292 comments
# 71 2
# 71 1
# Time elapsed for comments on video Xps3xjFyQSg 1.5154900550842285 for 393 comments
# 72 2
# 72 1
# Time elapsed for comments on video R-WHObwg2pE 1.3254315853118896 for 384 comments
# 73 2
# 73 1
# Time elapsed for comments on video XaYqOyqbXzw 0.3591909408569336 for 58 comments
# 74 2
# 74 1
# Time elapsed for comments on video 7aWGLOJngRQ 1.4862394332885742 for 442 comments
# 75 2
# 75 1
# Time elapsed for comments on video WhmmjKIiXoM 0.5904440879821777 for 184 comments
# 76 2
# 76 1
# Time elapsed for comments on video zq7gwoBkrxA 0.2781083583831787 for 73 comments
# 77 2
# 77 1
# Time elapsed for comments on video -GRWXh0VePo 0.5774710178375244 for 197 comments
# 78 2
# 78 1
# Time elapsed for comments on video zL0OD1lf5Dc 0.832611083984375 for 229 comments
# 79 2
# 79 1
# Time elapsed for comments on video x-b1h3e9ei8 0.8077011108398438 for 222 comments
# 80 2
# 80 1
# Time elapsed for comments on video ahUHn34n-DE 0.7221384048461914 for 177 comments
# 81 2
# 81 1
# Time elapsed for comments on video deW3JBKtXuM 1.9497301578521729 for 561 comments
# 82 2
# 82 1
# Time elapsed for comments on video xTpfAIsPk6c 0.9306914806365967 for 258 comments
# 83 2
# 83 1
# Time elapsed for comments on video 0JmF60yOaQU 0.595656156539917 for 191 comments
# 84 2
# 84 1
# Time elapsed for comments on video Ficu24szuU8 0.5883150100708008 for 196 comments
# 85 2
# 85 1
# Time elapsed for comments on video fqQ0CqyoZ70 0.613771915435791 for 196 comments
# 86 2
# 86 1
# Time elapsed for comments on video 3aAQl-FjJlE 1.2052817344665527 for 385 comments
# 87 2
# 87 1
# Time elapsed for comments on video Q4QKS7vc95k 1.4872915744781494 for 445 comments
# 88 2
# 88 1
# Time elapsed for comments on video qTBoJBcIQZ4 1.5274231433868408 for 365 comments
# 89 2
# 89 1
# Time elapsed for comments on video Bah4t1wjfn0 1.5953447818756104 for 406 comments
# 90 2
# 90 1
# Time elapsed for comments on video yRYUihh7hwY 0.8569564819335938 for 233 comments
# 91 2
# 91 1
# Time elapsed for comments on video Q3dRSQc_xAw 0.8392646312713623 for 249 comments
# 92 2
# 92 1
# Time elapsed for comments on video IlH33R3BXZI 1.1689229011535645 for 344 comments
# 93 2
# 93 1
# Time elapsed for comments on video Z3TDPuX4gnM 1.1239395141601562 for 318 comments
# 94 2
# 94 1
# Time elapsed for comments on video bO-dRf7AIas 2.320175886154175 for 632 comments
# 95 2
# 95 1
# Time elapsed for comments on video rtmGCbZBjZE 0.909013032913208 for 281 comments
# 96 2
# 96 1
# Time elapsed for comments on video BV0eBradTc0 0.5827507972717285 for 169 comments
# 97 2
# 97 1
# Time elapsed for comments on video uZjD_hbjt5A 2.0521109104156494 for 602 comments
# 98 2
# 98 1
# Time elapsed for comments on video 4BNgV2bWh6c 0.8724055290222168 for 294 comments
# 99 2
# 99 1
# Time elapsed for comments on video jfR7b-oUAeA 1.0315871238708496 for 214 comments
# 100 2
# 100 1
# Time elapsed for comments on video jHjWS0OsBQk 0.5467789173126221 for 160 comments
# 101 2
# 101 1
# Time elapsed for comments on video XLi1_gN3RBU 2.731247663497925 for 876 comments
# 102 2
# 102 1
# Time elapsed for comments on video CIvyBY83owg 0.8813703060150146 for 221 comments
# 103 2
# 103 1
# Time elapsed for comments on video dHWNMrItqrE 0.9302151203155518 for 261 comments
# 104 2
# 104 1
# Time elapsed for comments on video BWMpoW4U308 1.1804993152618408 for 395 comments
# 105 2
# 105 1
# Time elapsed for comments on video d_I2J8MHP88 1.8748435974121094 for 513 comments
# 106 2
# 106 1
# Time elapsed for comments on video N4i2dNDAawE 6.235344171524048 for 1915 comments
# 107 2
# 107 1
# Time elapsed for comments on video aQTGm-vKGRU 0.6201198101043701 for 121 comments
# 108 2
# 108 1
# Time elapsed for comments on video -tFeORhXL5s 0.6488375663757324 for 200 comments
# 109 2
# 109 1
# Time elapsed for comments on video 7wwC9kRQiCE 0.5197501182556152 for 127 comments
# 110 2
# 110 1
# Time elapsed for comments on video fY6cCvSL3gQ 0.8572049140930176 for 226 comments
# 111 2
# 111 1
# Time elapsed for comments on video tF2xSDNbncM 0.7182760238647461 for 195 comments
# 112 2
# 112 1
# Time elapsed for comments on video eSMNSwENrMA 0.9368059635162354 for 208 comments
# 113 2
# 113 1
# Time elapsed for comments on video QVDxhlizemg 0.5821592807769775 for 180 comments
# 114 2
# 114 1
# Time elapsed for comments on video 4CwDFMc57Y0 1.2391643524169922 for 355 comments
# 115 2
# 115 1
# Time elapsed for comments on video A0PGCiS1V4g 0.5143144130706787 for 106 comments
# 116 2
# 116 1
# Time elapsed for comments on video rWgP_yGM1Wg 0.30242109298706055 for 90 comments
# 117 2
# 117 1
# Time elapsed for comments on video wWHIOMu3qis 0.8980269432067871 for 217 comments
# 118 2
# 118 1
# Time elapsed for comments on video kCW2MQNBk2w 1.187591552734375 for 320 comments
# 119 2
# 119 1
# Time elapsed for comments on video FIVeIy18Z9o 2.5464601516723633 for 399 comments
# 120 2
# 120 1
# Time elapsed for comments on video rHt4KYGToZE 2.845845937728882 for 936 comments
# 121 2
# 121 1
# Time elapsed for comments on video q2IAGrnVDVs 0.8610429763793945 for 232 comments
# 122 2
# 122 1
# Time elapsed for comments on video EROjgzgS340 2.029017448425293 for 618 comments
# 123 2
# 123 1
# Time elapsed for comments on video dPrtGTYXY80 0.8495583534240723 for 211 comments
# 124 2
# 124 1
# Time elapsed for comments on video H87MkJJiXz8 1.283524513244629 for 378 comments
# 125 2
# 125 1
# Time elapsed for comments on video y6p-xDoyvXI 0.5924382209777832 for 110 comments
# 126 2
# 126 1
# Time elapsed for comments on video W6MqHHdWhSI 1.2465531826019287 for 364 comments
# 127 2
# 127 1
# Time elapsed for comments on video V9YeXCLh8Xc 3.118210792541504 for 946 comments
# 128 2
# 128 1
# Time elapsed for comments on video 17paElyk0d4 1.8443102836608887 for 487 comments
# 129 2
# 129 1
# Time elapsed for comments on video r_G5QdUjZ3c 1.9764213562011719 for 533 comments
# 130 2
# 130 1
# Time elapsed for comments on video rRQ5jk5kTjg 0.6224277019500732 for 135 comments
# 131 2
# 131 1
# Time elapsed for comments on video bSYNEkkuhoA 2.4622812271118164 for 740 comments
# 132 2
# 132 1
# Time elapsed for comments on video YJyvjnBRxEQ 1.6130173206329346 for 492 comments
# 133 2
# 133 1
# Time elapsed for comments on video Y1IyHBqTYDY 1.676661491394043 for 508 comments
# 134 2
# 134 1
# Time elapsed for comments on video BcruuWQ2_9Q 3.437211275100708 for 1086 comments
# 135 2
# 135 1
# Time elapsed for comments on video dTVirqziPIc 4.14498496055603 for 1270 comments
# 136 2
# 136 1
# Time elapsed for comments on video P5XbL10FbaM 1.9612035751342773 for 609 comments
# 137 2
# 137 1
# Time elapsed for comments on video 7IcD27_JqE0 4.990204572677612 for 1420 comments
# 138 2
# 138 1
# Time elapsed for comments on video TpvBy-07uW8 2.6821742057800293 for 862 comments
# 139 2
# 139 1
# Time elapsed for comments on video 93PxGfbnWlw 2.42248797416687 for 725 comments
# 140 2
# 140 1
# Time elapsed for comments on video 06qkCOdHHlU 5.126307010650635 for 1612 comments
# 141 2
# 141 1
# Time elapsed for comments on video Hndpk6A4VcE 3.8602724075317383 for 1126 comments
# 142 2
# 142 1
# Time elapsed for comments on video BZ6V0Tr6Bic 0.9021482467651367 for 251 comments
# 143 2
# 143 1
# Time elapsed for comments on video 5bh5Np7wSsA 2.03642201423645 for 665 comments
# 144 2
# 144 1
# Time elapsed for comments on video lKVusWwRJLE 2.1655642986297607 for 326 comments
# 145 2
# 145 1
# Time elapsed for comments on video 1R0Xgq1bxZI 2.937150239944458 for 778 comments
# 146 2
# 146 1
# Time elapsed for comments on video ibHsYxeJgEE 2.485274076461792 for 799 comments
# 147 2
# 147 1
# Time elapsed for comments on video qTQdS_gGKTI 1.9081354141235352 for 565 comments
# 148 2
# 148 1
# Time elapsed for comments on video Z00-9MhEw5o 1.3486886024475098 for 359 comments
# 149 2
# 149 1
# Time elapsed for comments on video OaqcWC8il5Q 1.2874197959899902 for 333 comments
# 150 2
# 150 1
# Time elapsed for comments on video GUG2FXHPXAA 2.7612998485565186 for 884 comments
# 151 2
# 151 1
# Time elapsed for comments on video tR9Lu1V69lg 1.112708568572998 for 303 comments
# 152 2
# 152 1
# Time elapsed for comments on video 3LT0wjBR-Xw 3.673236131668091 for 1147 comments
# 153 2
# 153 1
# Time elapsed for comments on video nrXQderuBg0 11.281448125839233 for 3157 comments
# 154 2
# 154 1
# Time elapsed for comments on video qXDu-Ca88pw 1.2134418487548828 for 338 comments
# 155 2
# 155 1
# Time elapsed for comments on video Dw8UoyUzc94 0.8011212348937988 for 232 comments
# 156 2
# 156 1
# Time elapsed for comments on video Vlnyb2v8KSA 2.510711908340454 for 791 comments
# 157 2
# 157 1
# Time elapsed for comments on video OgbA5cuWBOo 2.2889838218688965 for 716 comments
# 158 2
# 158 1
# Time elapsed for comments on video -z9M-UxfOOc 1.162449598312378 for 363 comments
# 159 2
# 159 1
# Time elapsed for comments on video jI_WWNkJQvM 0.8911900520324707 for 249 comments
# 160 2
# 160 1
# Time elapsed for comments on video fw7K_TTVjoo 0.7126049995422363 for 173 comments
# 161 2
# 161 1
# Time elapsed for comments on video MOCPiDrtREE 2.1488022804260254 for 601 comments
# 162 2
# 162 1
# Time elapsed for comments on video mwpHSMv1pI4 3.378922462463379 for 1091 comments
# 163 2
# 163 1
# Time elapsed for comments on video Gvh-LPpgKxg 3.0788750648498535 for 808 comments
# 164 2
# 164 1
# Time elapsed for comments on video 9Lro7mw2ubo 2.552703857421875 for 613 comments
# 165 2
# 165 1
# Time elapsed for comments on video k9geJRAhCHA 5.738468170166016 for 1770 comments
# 166 2
# 166 1
# Time elapsed for comments on video zoBhNsnD14k 3.393946647644043 for 998 comments
# 167 2
# 167 1
# Time elapsed for comments on video EE75Z3F-q7I 6.176818609237671 for 1817 comments
# 168 2
# 168 1
# Time elapsed for comments on video JuRawRS4tBU 0.8692309856414795 for 232 comments
# 169 2
# 169 1
# Time elapsed for comments on video aLhdWH8XRgM 1.369396686553955 for 370 comments
# 170 2
# 170 1
# Time elapsed for comments on video WwsJ2YkYbI8 6.92540168762207 for 669 comments
# 171 2
# 171 1
# Time elapsed for comments on video VcFy65dhqjQ 0.9553568363189697 for 288 comments
# 172 2
# 172 1
# Time elapsed for comments on video YjtRY28Pe2o 1.2300667762756348 for 296 comments
# 173 2
# 173 1
# Time elapsed for comments on video RbXYadQw1C4 0.9975419044494629 for 289 comments
# 174 2
# 174 1
# Time elapsed for comments on video 5pPC7j3yvRc 0.5684726238250732 for 160 comments
# 175 2
# 175 1
# Time elapsed for comments on video UbLksLGH78A 2.1145803928375244 for 524 comments
# 176 2
# 176 1
# Time elapsed for comments on video H_OTfEdct_0 0.9510674476623535 for 231 comments
# 177 2
# 177 1
# Time elapsed for comments on video gSAtdiwLaOA 1.8879587650299072 for 525 comments
# 178 2
# 178 1
# Time elapsed for comments on video k5gMl5cJZyU 0.562654972076416 for 145 comments
# 179 2
# 179 1
# Time elapsed for comments on video dKitekbnxPQ 0.6257185935974121 for 199 comments
# 180 2
# 180 1
# Time elapsed for comments on video dpMFGr-wznc 6.105537176132202 for 1827 comments
# 181 2
# 181 1
# Time elapsed for comments on video lND7W8edJoQ 2.631046772003174 for 711 comments
# 182 2
# 182 1
# Time elapsed for comments on video VgbTssOYoiw 4.141279220581055 for 1081 comments
# 183 2
# 183 1
# Time elapsed for comments on video NYD9ByC0c_I 1.5519287586212158 for 471 comments
# 184 2
# 184 1
# Time elapsed for comments on video s4DQbuO9TLY 0.842923641204834 for 236 comments
# 185 2
# 185 1
# Time elapsed for comments on video ThC7CqNrW3E 2.981968402862549 for 833 comments
# 186 2
# 186 1
# Time elapsed for comments on video JWhk_c0qwqc 1.6839416027069092 for 536 comments
# 187 2
# 187 1
# Time elapsed for comments on video rqhNs21h9jc 3.9068095684051514 for 1129 comments
# 188 2
# 188 1
# Time elapsed for comments on video Va1gleCM9b4 2.0555574893951416 for 652 comments
# 189 2
# 189 1
# Time elapsed for comments on video -2uhK7-Uphg 2.5514559745788574 for 755 comments
# 190 2
# 190 1
# Time elapsed for comments on video v4vEEsHTqv0 1.1619162559509277 for 341 comments
# 191 2
# 191 1
# Time elapsed for comments on video hLWgXvfwNVU 5.572439908981323 for 1795 comments
# 192 2
# 192 1
# Time elapsed for comments on video mZrx6d529uk 2.759887456893921 for 838 comments
# 193 2
# 193 1
# Time elapsed for comments on video 42Olc0HYisc 1.1956758499145508 for 388 comments
# 194 2
# 194 1
# Time elapsed for comments on video 0MEHEUm6DIA 7.290398359298706 for 2167 comments
# 195 2
# 195 1
# Time elapsed for comments on video XhPOOEq7VYU 1.557922601699829 for 461 comments
# 196 2
# 196 1
# Time elapsed for comments on video wqF2lJajSxs 1.726830005645752 for 504 comments
# 197 2
# 197 1
# Time elapsed for comments on video LdhWLCWPi1w 0.26806640625 for 44 comments
# 198 2
# 198 1
# Time elapsed for comments on video z3MFOEtaaoI 1.7665798664093018 for 511 comments
# 199 2
# 199 1
# Time elapsed for comments on video 2jBqIbDe6RY 2.6096959114074707 for 806 comments
# 200 2
# 200 1
# Time elapsed for comments on video P8Ice1eBq4Y 2.9938011169433594 for 864 comments
# 201 2
# 201 1
# Time elapsed for comments on video wgVXRxZEniw 1.2598624229431152 for 371 comments
# 202 2
# 202 1
# Time elapsed for comments on video pu5K6tLbAvQ 1.9119594097137451 for 515 comments
# 203 2
# 203 1
# Time elapsed for comments on video akRJrg1u6o4 2.4510152339935303 for 769 comments
# 204 2
# 204 1
# Time elapsed for comments on video AHzza5qkX7A 0.6014676094055176 for 163 comments
# 205 2
# 205 1
# Time elapsed for comments on video qLeO7wwLPE4 1.9628455638885498 for 577 comments
# 206 2
# 206 1
# Time elapsed for comments on video -ydyXIk2wck 2.4635143280029297 for 757 comments
# 207 2
# 207 1
# Time elapsed for comments on video 4N5LDQkIIc4 2.9389829635620117 for 808 comments
# 208 2
# 208 1
# Time elapsed for comments on video 8UelSto6Glk 2.5319983959198 for 743 comments
# 209 2
# 209 1
# Time elapsed for comments on video o5ejxJ9pcEE 2.542515277862549 for 761 comments
# 210 2
# 210 1
# Time elapsed for comments on video odh2lOA0P-s 3.817622423171997 for 1168 comments
# 211 2
# 211 1
# Time elapsed for comments on video i1xSrcCDzEw 1.725172996520996 for 488 comments
# 212 2
# 212 1
# Time elapsed for comments on video S7SBjkdw4M0 3.417497396469116 for 1058 comments
# 213 2
# 213 1
# Time elapsed for comments on video V0Qf7pVdDhc 2.285984992980957 for 678 comments
# 214 2
# 214 1
# Time elapsed for comments on video 5Rk8M-ipepk 4.246303081512451 for 1316 comments
# 215 2
# 215 1
# Time elapsed for comments on video dk96M05hJx8 4.57494330406189 for 1413 comments
# 216 2
# 216 1
# Time elapsed for comments on video sGCOnsjW5As 3.5176095962524414 for 1098 comments
# 217 2
# 217 1
# Time elapsed for comments on video KzLtB4Ty7lY 8.420501708984375 for 2532 comments
# 218 2
# 218 1
# Time elapsed for comments on video DoAhs_VsFW4 17.455301761627197 for 5358 comments
# 219 2
# 219 1
# Time elapsed for comments on video Ack7QaiRCUs 2.2159016132354736 for 681 comments
# 220 2
# 220 1
# Time elapsed for comments on video yNKo_BQhLuw 2.4031898975372314 for 664 comments
# 221 2
# 221 1
# Time elapsed for comments on video Gyo_sIOCM-s 0.6596992015838623 for 194 comments
# 222 2
# 222 1
# Time elapsed for comments on video tZqnxp_xr0c 2.182177782058716 for 604 comments
# 223 2
# 223 1
# Time elapsed for comments on video iS3JMw1yIwA 4.078887224197388 for 1223 comments
# 224 2
# 224 1
# Time elapsed for comments on video E9UrEqAqVrM 1.480846643447876 for 382 comments
# 225 2
# 225 1
# Time elapsed for comments on video OnSItYNoyJc 1.8018603324890137 for 519 comments
# 226 2
# 226 1
# Time elapsed for comments on video 3HUey4BLP9c 3.418426036834717 for 1070 comments
# 227 2
# 227 1
# Time elapsed for comments on video xgPXcUTnKIc 1.936650276184082 for 587 comments
# 228 2
# 228 1
# Time elapsed for comments on video pVj6RMZ9W0g 1.3138389587402344 for 386 comments
# 229 2
# 229 1
# Time elapsed for comments on video rWfd704oLcQ 2.20707106590271 for 618 comments
# 230 2
# 230 1
# Time elapsed for comments on video rG_l4HaAqxc 1.0154476165771484 for 269 comments
# 231 2
# 231 1
# Time elapsed for comments on video 0fGNaBDuK6E 2.227116584777832 for 679 comments
# 232 2
# 232 1
# Time elapsed for comments on video Q9ncSkSPIbI 2.9484846591949463 for 822 comments
# 233 2
# 233 1
# Time elapsed for comments on video y_FnQ7lN8Gw 1.5286860466003418 for 470 comments
# 234 2
# 234 1
# Time elapsed for comments on video ccYJwPLqMSA 2.465095043182373 for 717 comments
# 235 2
# 235 1
# Time elapsed for comments on video R6EsV3jX6AU 2.2817442417144775 for 608 comments
# 236 2
# 236 1
# Time elapsed for comments on video 3CzGZpBQYm0 1.3230950832366943 for 392 comments
# 237 2
# 237 1
# Time elapsed for comments on video vi3V3dlXN38 2.2171871662139893 for 680 comments
# 238 2
# 238 1
# Time elapsed for comments on video O0k6PBzCQuU 2.596911907196045 for 793 comments
# 239 2
# 239 1
# Time elapsed for comments on video oTVIi5z8WtY 3.181849479675293 for 1006 comments
# 240 2
# 240 1
# Time elapsed for comments on video k3yR45UlVNY 0.583885908126831 for 168 comments
# 241 2
# 241 1
# Time elapsed for comments on video 9uTvwpNU84o 1.5975186824798584 for 452 comments
# 242 2
# 242 1
# Time elapsed for comments on video M92JsauTagM 3.1523053646087646 for 987 comments
# 243 2
# 243 1
# Time elapsed for comments on video 63yp2ZCU9Bg 2.8509695529937744 for 819 comments
# 244 2
# 244 1
# Time elapsed for comments on video Qe6Yl9sgGjw 0.8602190017700195 for 234 comments
# 245 2
# 245 1
# Time elapsed for comments on video BIHMuJm2_tE 0.6883392333984375 for 196 comments
# 246 2
# 246 1
# Time elapsed for comments on video SV5wZzz-Y7M 4.061627149581909 for 1254 comments
# 247 2
# 247 1
# Time elapsed for comments on video 95jUNvCWCGw 2.9052340984344482 for 853 comments
# 248 2
# 248 1
# Time elapsed for comments on video LWHRGasjjdA 1.9372892379760742 for 566 comments
# 249 2
# 249 1
# Time elapsed for comments on video sc_70v4U4PA 2.227047920227051 for 674 comments
# 250 2
# 250 1
# Time elapsed for comments on video hRD4QKiyU3w 2.6638355255126953 for 769 comments
# 251 2
# 251 1
# Time elapsed for comments on video pDMRi3w7cSU 2.565500259399414 for 632 comments
# 252 2
# 252 1
# Time elapsed for comments on video 8wSw8NF-K9o 3.394024610519409 for 1036 comments
# 253 2
# 253 1
# Time elapsed for comments on video V1Xmb7rEOAA 2.9421072006225586 for 854 comments
# 254 2
# 254 1
# Time elapsed for comments on video KRyJg2quQ7o 1.6904959678649902 for 479 comments
# 255 2
# 255 1
# Time elapsed for comments on video 4kLTWrXTM-k 3.122793674468994 for 869 comments
# 256 2
# 256 1
# Time elapsed for comments on video zL2SBpJbfHk 1.398364543914795 for 371 comments
# 257 2
# 257 1
# Time elapsed for comments on video YhdFS16CgKo 1.189932107925415 for 347 comments
# 258 2
# 258 1
# Time elapsed for comments on video itwuZzaZ7eA 1.7392613887786865 for 454 comments
# 259 2
# 259 1
# Time elapsed for comments on video 3mZizOTh0KY 4.4002766609191895 for 1371 comments
# 260 2
# 260 1
# Time elapsed for comments on video TpEcIiSamrM 2.1334521770477295 for 688 comments
# 261 2
# 261 1
# Time elapsed for comments on video 0kU5HdPhI1g 3.0135815143585205 for 834 comments
# 262 2
# 262 1
# Time elapsed for comments on video P40dLlvoAoA 2.2979350090026855 for 464 comments
# 263 2
# 263 1
# Time elapsed for comments on video maIqBhtTxrQ 53.55920696258545 for 14559 comments
# 264 2
# 264 1
# Time elapsed for comments on video vcdbVeX1518 4.466625690460205 for 1347 comments
# 265 2
# 265 1
# Time elapsed for comments on video 4lnwrhMIrNQ 7.520357608795166 for 2182 comments
# 266 2
# 266 1
# Time elapsed for comments on video ZnjUW4hjrO4 5.270991563796997 for 1624 comments
# 267 2
# 267 1
# Time elapsed for comments on video OLDaz-SrW6U 1.909186840057373 for 506 comments
# 268 2
# 268 1
# Time elapsed for comments on video b4u-f0ErY2g 4.035362243652344 for 1238 comments
# 269 2
# 269 1
# Time elapsed for comments on video z5MVdzKy9NU 2.850771188735962 for 743 comments
# 270 2
# 270 1
# Time elapsed for comments on video LS8nJJnnij0 0.913276195526123 for 297 comments
# 271 2
# 271 1
# Time elapsed for comments on video ENVSZd0z-dI 0.959428071975708 for 264 comments
# 272 2
# 272 1
# Time elapsed for comments on video t1aWzLT4Plk 2.173743963241577 for 685 comments
# 273 2
# 273 1
# Time elapsed for comments on video cT8PcwHFSqg 1.6448395252227783 for 511 comments
# 274 2
# 274 1
# Time elapsed for comments on video 0u4liaEm_Fk 4.595343112945557 for 1418 comments
# 275 2
# 275 1
# Time elapsed for comments on video 4jeecodk0HI 1.2779550552368164 for 373 comments
# 276 2
# 276 1
# Time elapsed for comments on video 6QY5O_y-5I8 4.745874643325806 for 1361 comments
# 277 2
# 277 1
# Time elapsed for comments on video MVf6sEqpLLA 1.415715217590332 for 372 comments
# 278 2
# 278 1
# Time elapsed for comments on video hJl-h3zKgYU 2.5978262424468994 for 743 comments
# 279 2
# 279 1
# Time elapsed for comments on video mkOXGzKWkcg 4.60527491569519 for 1442 comments
# 280 2
# 280 1
# Time elapsed for comments on video B1EC1Uzhszk 1.8890125751495361 for 528 comments
# 281 2
# 281 1
# Time elapsed for comments on video jFS36D5e1iI 5.442843675613403 for 1699 comments
# 282 2
# 282 1
# Time elapsed for comments on video JlXRmZFhhLI 2.874181032180786 for 897 comments
# 283 2
# 283 1
# Time elapsed for comments on video T2VmStNf7I0 2.6472232341766357 for 797 comments
# 284 2
# 284 1
# Time elapsed for comments on video wD0qYaHCppU 0.9984972476959229 for 300 comments
# 285 2
# 285 1
# Time elapsed for comments on video QCJin8ONvtU 2.4327778816223145 for 507 comments
# 286 2
# 286 1
# Time elapsed for comments on video aRRa80C-vpw 1.5072031021118164 for 464 comments
# 287 2
# 287 1
# Time elapsed for comments on video cBdKqDVlO-M 1.9705631732940674 for 558 comments
# 288 2
# 288 1
# Time elapsed for comments on video JTy3rVr04ck 2.3453433513641357 for 634 comments
# 289 2
# 289 1
# Time elapsed for comments on video _BqNL_zT9uI 0.9233403205871582 for 251 comments
# 290 2
# 290 1
# Time elapsed for comments on video wbMmhqqo6hM 2.081897258758545 for 582 comments
# 291 2
# 291 1
# Time elapsed for comments on video DuTZChmf5q4 1.763530969619751 for 524 comments
# 292 2
# 292 1
# Time elapsed for comments on video wLSKRTg8v1g 3.555516242980957 for 1025 comments
# 293 2
# 293 1
# Time elapsed for comments on video LjYkMQpnvC4 2.33210825920105 for 662 comments
# 294 2
# 294 1
# Time elapsed for comments on video nXzq-G3L_IQ 1.9537763595581055 for 535 comments
# 295 2
# 295 1
# Time elapsed for comments on video aQrZwjgV5Hc 1.5462942123413086 for 426 comments
# 296 2
# 296 1
# Time elapsed for comments on video jsiED2F0Tpc 2.136284828186035 for 585 comments
# 297 2
# 297 1
# Time elapsed for comments on video pj0YLAMIpb0 1.309614896774292 for 372 comments
# 298 2
# 298 1
# Time elapsed for comments on video 82Vhz3A1hSA 2.8284175395965576 for 882 comments
# 299 2
# 299 1
# Time elapsed for comments on video qG7NR731P_w 0.9989328384399414 for 274 comments
# 300 2
# 300 1
# Time elapsed for comments on video pxBUuzovGw4 2.5373759269714355 for 789 comments
# 301 2
# 301 1
# Time elapsed for comments on video na08pLHKbo4 3.6903820037841797 for 1139 comments
# 302 2
# 302 1
# Time elapsed for comments on video bZa3nZu2lK8 1.325148105621338 for 317 comments
# 303 2
# 303 1
# Time elapsed for comments on video j9rJGlRlNw8 2.1329612731933594 for 647 comments
# 304 2
# 304 1
# Time elapsed for comments on video xKKifGocP6o 3.265766143798828 for 824 comments
# 305 2
# 305 1
# Time elapsed for comments on video zkOxTfh8C7g 2.3180298805236816 for 628 comments
# 306 2
# 306 1
# Time elapsed for comments on video VqmwyFbA6S0 3.195953369140625 for 892 comments
# 307 2
# 307 1
# Time elapsed for comments on video j1cdGWI9x3g 13.205450296401978 for 3880 comments
# 308 2
# 308 1
# Time elapsed for comments on video ABdsgP1ZYfM 0.9103658199310303 for 282 comments
# 309 2
# 309 1
# Time elapsed for comments on video PM3uR3VOcz0 2.4634101390838623 for 763 comments
# 310 2
# 310 1
# Time elapsed for comments on video FhYAbTBDylc 3.908737897872925 for 1164 comments
# 311 2
# 311 1
# Time elapsed for comments on video 9T-UxMbsKCE 3.549628973007202 for 886 comments
# 312 2
# 312 1
# Time elapsed for comments on video BYpxIqjqTqE 1.863128423690796 for 584 comments
# 313 2
# 313 1
# Time elapsed for comments on video nVCLCgn_9vk 2.27791690826416 for 643 comments
# 314 2
# 314 1
# Time elapsed for comments on video FYpyDEf4X0g 1.2651252746582031 for 399 comments
# 315 2
# 315 1
# Time elapsed for comments on video z_2MHmrPEGs 1.9512767791748047 for 574 comments
# 316 2
# 316 1
# Time elapsed for comments on video ov2sdjkNgxk 9.28520393371582 for 2658 comments
# 317 2
# 317 1
# Time elapsed for comments on video -D9xXh9P9ec 4.666619300842285 for 1464 comments
# 318 2
# 318 1
# Time elapsed for comments on video cDYyZn4_08g 0.9449899196624756 for 294 comments
# 319 2
# 319 1
# Time elapsed for comments on video aCmCJPlxCTI 3.068925380706787 for 899 comments
# 320 2
# 320 1
# Time elapsed for comments on video MQpylBD_fxY 3.062670946121216 for 832 comments
# 321 2
# 321 1
# Time elapsed for comments on video YzIk-PBayS4 2.787897825241089 for 802 comments
# 322 2
# 322 1
# Time elapsed for comments on video KIlHMBPg1tg 2.189344882965088 for 631 comments
# 323 2
# 323 1
# Time elapsed for comments on video AkuHpyI8Sh4 4.547698974609375 for 1361 comments
# 324 2
# 324 1
# Time elapsed for comments on video g9Dk_ASjRQw 5.167888641357422 for 1361 comments
# 325 2
# 325 1
# Time elapsed for comments on video AuSS8nCPPPo 1.0889034271240234 for 303 comments
# 326 2
# 326 1
# Time elapsed for comments on video VRFvYbbAG4Y 2.4729933738708496 for 777 comments
# 327 2
# 327 1
# Time elapsed for comments on video DZDshg3gUSA 2.3968820571899414 for 712 comments
# 328 2
# 328 1
# Time elapsed for comments on video UF_XTeJVCXU 6.442570686340332 for 1891 comments
# 329 2
# 329 1
# Time elapsed for comments on video xpDkxcgj66Y 18.860886335372925 for 5799 comments
# 330 2
# 330 1
# Time elapsed for comments on video 0Mp8MxDURxY 0.9341754913330078 for 275 comments
# 331 2
# 331 1
# Time elapsed for comments on video b62LwWzkj3s 1.3431029319763184 for 336 comments
# 332 2
# 332 1
# Time elapsed for comments on video 3rWmP2aLDvU 2.859117031097412 for 812 comments
# 333 2
# 333 1
# Time elapsed for comments on video 7ttCrMlWOsA 2.2388272285461426 for 674 comments
# 334 2
# 334 1
# Time elapsed for comments on video XoeMOdDTcLw 2.9352526664733887 for 809 comments
# 335 2
# 335 1
# Time elapsed for comments on video GYHdrH9O5b4 2.970871925354004 for 719 comments
# 336 2
# 336 1
# Time elapsed for comments on video IX_KEaYLwSQ 1.6101980209350586 for 426 comments
# 337 2
# 337 1
# Time elapsed for comments on video 7UaEioQjOpM 6.480844736099243 for 1894 comments
# 338 2
# 338 1
# Time elapsed for comments on video 2kHyiQs0wkc 2.325162887573242 for 624 comments
# 339 2
# 339 1
# Time elapsed for comments on video t50iFXh-zdU 7.754053115844727 for 2263 comments
# 340 2
# 340 1
# Time elapsed for comments on video 73DZ3XzKtc8 3.3138797283172607 for 884 comments
# 341 2
# 341 1
# Time elapsed for comments on video lcNZ0eMVqIg 4.4873480796813965 for 933 comments
# 342 2
# 342 1
# Time elapsed for comments on video hvJ8pJdDw-0 2.77827787399292 for 863 comments
# 343 2
# 343 1
# Time elapsed for comments on video fcvhSl7-2bw 0.9722497463226318 for 220 comments
# 344 2
# 344 1
# Time elapsed for comments on video b9DMw-1PFnQ 1.4989545345306396 for 422 comments
# 345 2
# 345 1
# Time elapsed for comments on video NJEmK7u4WF4 0.6490185260772705 for 155 comments
# 346 2
# 346 1
# Time elapsed for comments on video L-jCkfbpNCs 1.6720597743988037 for 490 comments
# 347 2
# 347 1
# Time elapsed for comments on video Aet5YK_Gu_U 2.5518791675567627 for 794 comments
# 348 2
# 348 1
# Time elapsed for comments on video 52M5sciGKw0 2.4115893840789795 for 732 comments
# 349 2
# 349 1
# Time elapsed for comments on video rNjef456Yyc 2.755174160003662 for 791 comments
# 350 2
# 350 1
# Time elapsed for comments on video eK2kglH3JSY 2.605520486831665 for 704 comments
# 351 2
# 351 1
# Time elapsed for comments on video vDAJdwwOhno 2.428473711013794 for 688 comments
# 352 2
# 352 1
# Time elapsed for comments on video wnahjU0WHxk 1.4854176044464111 for 460 comments
# 353 2
# 353 1
# Time elapsed for comments on video KUUy4gi3Uc0 1.9869935512542725 for 537 comments
# 354 2
# 354 1
# Time elapsed for comments on video MC09vwvQAUc 1.948714256286621 for 542 comments
# 355 2
# 355 1
# Time elapsed for comments on video qhihg2t81xQ 0.8916122913360596 for 267 comments
# 356 2
# 356 1
# Time elapsed for comments on video Mmp8ivBXDIg 2.469404458999634 for 718 comments
# 357 2
# 357 1
# Time elapsed for comments on video oSyfYNTTs6E 1.442525863647461 for 389 comments
# 358 2
# 358 1
# Time elapsed for comments on video _htZlYbA1IE 1.9087355136871338 for 503 comments
# 359 2
# 359 1
# Time elapsed for comments on video TaCJaSEWCV0 2.427961587905884 for 706 comments
# 360 2
# 360 1
# Time elapsed for comments on video fxbtFQmMy8Q 3.2065482139587402 for 999 comments
# 361 2
# 361 1
# Time elapsed for comments on video CJNd8qYA_68 2.2300896644592285 for 684 comments
# 362 2
# 362 1
# Time elapsed for comments on video qpJbMf_TVBY 3.1932058334350586 for 954 comments
# 363 2
# 363 1
# Time elapsed for comments on video AUilah3Ju7A 9.631234407424927 for 2750 comments
# 364 2
# 364 1
# Time elapsed for comments on video G_WwfFS-GAQ 1.8675034046173096 for 528 comments
# 365 2
# 365 1
# Time elapsed for comments on video Pq9IE5Okr44 1.2832255363464355 for 388 comments
# 366 2
# 366 1
# Time elapsed for comments on video XjtRQEEihi8 1.5078752040863037 for 443 comments
# 367 2
# 367 1
# Time elapsed for comments on video Xhw_xemJC4Q 0.9087872505187988 for 273 comments
# 368 2
# 368 1
# Time elapsed for comments on video 71PwX2KnSVw 20.0856990814209 for 6097 comments
# 369 2
# 369 1
# Time elapsed for comments on video J8G7fo-XRYg 2.171074867248535 for 625 comments
# 370 2
# 370 1
# Time elapsed for comments on video B_rWYeLdq7M 2.2070133686065674 for 700 comments
# 371 2
# 371 1
# Time elapsed for comments on video bZL8FFOOq9I 3.8610966205596924 for 1183 comments
# 372 2
# 372 1
# Time elapsed for comments on video SVy_qHDVLpg 3.7636947631835938 for 1134 comments
# 373 2
# 373 1
# Time elapsed for comments on video NwUueILNj-4 2.2223451137542725 for 626 comments
# 374 2
# 374 1
# Time elapsed for comments on video zGt1eOtcIQk 1.2821447849273682 for 382 comments
# 375 2
# 375 1
# Time elapsed for comments on video yla1qJiLSW8 2.2709176540374756 for 671 comments
# 376 2
# 376 1
# Time elapsed for comments on video 8ThFJ8i1_Lw 3.5012571811676025 for 1025 comments
# 377 2
# 377 1
# Time elapsed for comments on video nr92Xe_4CaY 2.5485332012176514 for 719 comments
# 378 2
# 378 1
# Time elapsed for comments on video mpmzOyOqcv4 2.1785314083099365 for 677 comments
# 379 2
# 379 1
# Time elapsed for comments on video gUmMBF7uYLQ 1.1180109977722168 for 298 comments
# 380 2
# 380 1
# Time elapsed for comments on video ONIbTeOTIlg 1.5931947231292725 for 428 comments
# 381 2
# 381 1
# Time elapsed for comments on video MOYcWQgF49g 2.4757063388824463 for 707 comments
# 382 2
# 382 1
# Time elapsed for comments on video 8aIZYSllDbg 3.3962767124176025 for 1045 comments
# 383 2
# 383 1
# Time elapsed for comments on video 3jNplV53kcQ 1.7799410820007324 for 467 comments
# 384 2
# 384 1
# Time elapsed for comments on video LQ75b6yxbro 2.9278526306152344 for 794 comments
# 385 2
# 385 1
# Time elapsed for comments on video xIPl_L6Y2z4 3.235852003097534 for 893 comments
# 386 2
# 386 1
# Time elapsed for comments on video kXDjl1GDO8c 1.2362680435180664 for 320 comments
# 387 2
# 387 1
# Time elapsed for comments on video sUPflBfdC2E 6.071110725402832 for 1861 comments
# 388 2
# 388 1
# Time elapsed for comments on video YBz_2ubvkvY 1.2770400047302246 for 336 comments
# 389 2
# 389 1
# Time elapsed for comments on video G796lNlksaw 2.4629008769989014 for 714 comments
# 390 2
# 390 1
# Time elapsed for comments on video y_odC3YTHXQ 1.240116834640503 for 340 comments
# 391 2
# 391 1
# Time elapsed for comments on video 8UvpEiM-FM8 2.0437285900115967 for 563 comments
# 392 2
# 392 1
# Time elapsed for comments on video DwNFl_OiwI4 2.352508306503296 for 638 comments
# 393 2
# 393 1
# Time elapsed for comments on video 9ZStuUp5jI0 1.9140677452087402 for 541 comments
# 394 2
# 394 1
# Time elapsed for comments on video a3oVwq1kbgs 1.4513885974884033 for 317 comments
# 395 2
# 395 1
# Time elapsed for comments on video FIjvSP9N3Lk 2.1964712142944336 for 687 comments
# 396 2
# 396 1
# Time elapsed for comments on video NP9LwDOMRHo 1.8185150623321533 for 540 comments
# 397 2
# 397 1
# Time elapsed for comments on video pb7snTVMiOM 3.487058162689209 for 1002 comments
# 398 2
# 398 1
# Time elapsed for comments on video YEJc7TWZ1Kc 2.6999213695526123 for 815 comments
# 399 2
# 399 1
# Time elapsed for comments on video jZ6T9qol4R4 0.9198908805847168 for 281 comments
# 400 2
# 400 1
# Time elapsed for comments on video S5GW5QWMTFw 2.5551209449768066 for 761 comments
# 401 2
# 401 1
# Time elapsed for comments on video WOibSCAt1YM 1.5545942783355713 for 492 comments
# 402 2
# 402 1
# Time elapsed for comments on video 3tO6kmdiVVk 2.2394778728485107 for 700 comments
# 403 2
# 403 1
# Time elapsed for comments on video PSCzJAoLgBw 2.5542678833007812 for 702 comments
# 404 2
# 404 1
# Time elapsed for comments on video 3w-1AGkX10I 3.3106961250305176 for 1027 comments
# 405 2
# 405 1
# Time elapsed for comments on video gGG1ueVeQbE 1.4483952522277832 for 404 comments
# 406 2
# 406 1
# Time elapsed for comments on video wtGZt4phr6c 3.042898178100586 for 791 comments
# 407 2
# 407 1
# Time elapsed for comments on video C8x549wxlrY 0.9438934326171875 for 278 comments
# 408 2
# 408 1
# Time elapsed for comments on video q0799Q93gtI 1.928654670715332 for 566 comments
# 409 2
# 409 1
# Time elapsed for comments on video _sCzo0M03qs 16.08120822906494 for 4780 comments
# 410 2
# 410 1
# Time elapsed for comments on video fge883Uv4cY 2.5529937744140625 for 775 comments
# 411 2
# 411 1
# Time elapsed for comments on video V6We3cZadsE 2.438965082168579 for 719 comments
# 412 2
# 412 1
# Time elapsed for comments on video rexPX2WoWKo 3.684782028198242 for 1050 comments
# 413 2
# 413 1
# Time elapsed for comments on video 389TMUtqX3E 14.238013744354248 for 4082 comments
# 414 2
# 414 1
# Time elapsed for comments on video tLA0owfGXss 1.5013723373413086 for 462 comments
# 415 2
# 415 1
# Time elapsed for comments on video xERVUHnyHSg 2.060838460922241 for 550 comments
# 416 2
# 416 1
# Time elapsed for comments on video QQH53HDKkYA 1.794687271118164 for 587 comments
# 417 2
# 417 1
# Time elapsed for comments on video qNx5ZnpeugQ 1.3282058238983154 for 364 comments
# 418 2
# 418 1
# Time elapsed for comments on video DO2wi9ayAl0 1.537719488143921 for 404 comments
# 419 2
# 419 1
# Time elapsed for comments on video dBMw1xV4heg 1.571934700012207 for 442 comments
# 420 2
# 420 1
# Time elapsed for comments on video EI23CdUGwfk 1.566481590270996 for 495 comments
# 421 2
# 421 1
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pMU9wZkF0cnZNUVB3cGpOMVIzM0RiSXBBczhfMU1BUHFmY3lLXzJ0WWNvczl0MFpTcFozZWR4MEJXNEhWcEZEeEE0VGZzYTNmUQ==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pMExrenRqb05NMTJqbURZM3UzZEFhTkJIQXMydmFkcndOanFxRUhLanhtX1gzUVEtVzdieFNnTzBrZGNzaTJsYk9LVkp4ZHc5TQ==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pMWJOdTJrT2RVejJvN1BUTHVzYkgxaGxNZEJvZjVvMjl4U183dUM5MmNISU5ZR0F3azZodVdRbS1ZU1dMZTd0dFN4V1RFSjB3Zw==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pMFc0U0JEbGVJU1FOQnhtQmRfRGExanRBVnNqVFdjZUl6M1BaTnh1dXNSX3lPR3N0ZklQQldtWXF2N1BOQkFIRmE3V3JKRmNqQQ==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pM1hLUFBka2xJb3A3NXRCUlNEdVRwTWp2NlNiS2R0Y0hkWlZuX1VuMC1fby1HTkFkQ1l2YmFfcURzN1lsSDBqUXdBeF9wTkJPYw==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pMUVWNHFzLU5kX202ZDVLNWpyb2FyZVYxOU1jc3VKQmNab3BSQ3Q5cU9KMlNMRGxidE9QR0tDOXhqbE5oblJaZGtsaWozSG5fYw==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pMFhKTXdnVWZTaHZJaW9BdHRrZDI1NEpYRXRYT3NLWEpBN0Rpd2YyR1lMRkRaRWh1UWtNM01DYmdxVUg0cy1oSi0yLVp0X29mVQ==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page QURTSl9pM1NWZW9mcV9lUUVwUTE0UkE0SmdVdzYxSV94U2JSc2ZFWXkyaXQ2djlIb1I5aUFoMnJEYkZ1Q1A0ZFRtYnFXY1BTazA4eXYydw==
# 403 - The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>. - 8soK9uxXod4 with page
# Error caught while fetching comment data, ending execution
# 421 3

# %% [markdown]
# # Data Validation

# %%
test = pd.read_csv("Comment Data.csv")

# %%
test
# Out:
#         Unnamed: 0           Comment Thread ID     Video ID  \
# 0                0  Ugz4WtWC2lIxTbGJrDB4AaABAg  I0glbWBxeFc
# 1                1  UgwvNv08ik_Z2tSjt_l4AaABAg  I0glbWBxeFc
# 2                2  UgxwXahagCIZBWDhDGx4AaABAg  I0glbWBxeFc
# 3                3  Ugzq1LzKobwaMcWd0h14AaABAg  I0glbWBxeFc
# 4                4  UgyjlY7obLEHvJOXX6d4AaABAg  I0glbWBxeFc
# ...            ...                         ...          ...
# 303899      303899        Ugj-iR5-F5gM7XgCoAEC  EI23CdUGwfk
# 303900      303900        UggEwUJK9sXk_HgCoAEC  EI23CdUGwfk
# 303901      303901        UghzMEulBFiNv3gCoAEC  EI23CdUGwfk
# 303902      303902        UgizoF1UUWBQ7HgCoAEC  EI23CdUGwfk
# 303903      303903        UgiBbb92pkvPnngCoAEC  EI23CdUGwfk
#
#                                         Top Level Comment  Total Replies  \
# 0       {'kind': 'youtube#comment', 'etag': 'KnBhGhh-U...              0
# 1       {'kind': 'youtube#comment', 'etag': 'pxilHJCfv...              0
# 2       {'kind': 'youtube#comment', 'etag': 'GOkOyp340...              0
# 3       {'kind': 'youtube#comment', 'etag': 'n3GRzAD4-...              0
# 4       {'kind': 'youtube#comment', 'etag': '2wM6-YcA4...              0
# ...                                                   ...            ...
# 303899  {'kind': 'youtube#comment', 'etag': 'Io46ESXU5...              0
# 303900  {'kind': 'youtube#comment', 'etag': '1oBukmE1z...              0
# 303901  {'kind': 'youtube#comment', 'etag': '9Pf0ocN2k...              0
# 303902  {'kind': 'youtube#comment', 'etag': 'ceqyArhLY...              0
# 303903  {'kind': 'youtube#comment', 'etag': 'mtdGI4NmV...              1
#
#         Can Reply                                            Replies
# 0            True                                                NaN
# 1            True                                                NaN
# 2            True                                                NaN
# 3            True                                                NaN
# 4            True                                                NaN
# ...           ...                                                ...
# 303899       True                                                NaN
# 303900       True                                                NaN
# 303901       True                                                NaN
# 303902       True                                                NaN
# 303903       True  {'comments': [{'kind': 'youtube#comment', 'eta...
#
# [303904 rows x 7 columns]
